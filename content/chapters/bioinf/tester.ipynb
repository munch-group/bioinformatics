# %% [markdown]
# # Tester

# %%
import matplotlib.pyplot as plt
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina', 'png')
import seaborn as sns
sns.set()
sns.set_style("ticks")

# %%
#| label: fig-test
#| fig-cap: "This is a caption"
#| code-fold: true

plt.plot(list(range(10)), list(range(10)))
sns.despine()

# %%
radius = 10
from IPython.display import display, Markdown

# %%
#| echo: false
Markdown(f"""
                 
The radius of the circle is {radius} and the square is {radius**2}.

""")
# Out:
#
# The radius of the circle is 10 and the square is 100.

# %%
print('hello world')
# Out:
# hello world

# %%
#| label: tbl-planets
#| tbl-cap: Planets
#| echo: false

from IPython.display import Markdown
from tabulate import tabulate
table = [["Sun",696000,1989100000],
         ["Earth",6371,5973.6],
         ["Moon",1737,73.5],
         ["Mars",3390,641.85]]
Markdown(tabulate(
  table, 
  headers=["Planet","R (km)", "mass (x 10^29 kg)"]
))
# Out:
# Planet      R (km)    mass (x 10^29 kg)
# --------  --------  -------------------
# Sun         696000           1.9891e+09
# Earth         6371        5973.6
# Moon          1737          73.5
# Mars          3390         641.85

# %% [markdown]
# {{< embed chapters/bioinf/tester2.ipynb#fig-test2 >}}

# %% [markdown]
# {{< embed #fig-test >}}
